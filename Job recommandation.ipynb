# %%
import numpy as np
import pandas as pd
import re
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
dff= pd.read_csv("analyst.csv", sep=",")

# %%
dff.head()
# Out:
#                                                title    location  \
# 0  Credit Risk Analyst – Leading Renewable Energy...     Central
# 1  Financial Analyst, Google Customer Solutions -...       South
# 2                            Senior Business Analyst     Central
# 3          Senior Financial Analyst (Pharmaceutical)  Islandwide
# 4                    System Analyst (Java) (JD#4804)        East
#
#        employment_type                        level  \
# 0            Full Time                 Professional
# 1            Full Time                    Executive
# 2            Permanent                 Professional
# 3            Permanent             Senior Executive
# 4  Contract, Full Time  Executive, Senior Executive
#
#                                category salary_min salary_max salary_type  \
# 0  Risk Management, Banking and Finance        NaN        NaN         NaN
# 1                   Banking and Finance     $6,600  to$13,200     Monthly
# 2                Information Technology        NaN        NaN         NaN
# 3      Accounting / Auditing / Taxation        NaN        NaN         NaN
# 4                         Entertainment     $4,000   to$5,000     Monthly
#
#                                          description  \
# 0  Roles & Responsibilities\n• 6 years of relevan...
# 1  Roles & Responsibilities\nCompany overview:\nG...
# 2  Roles & Responsibilities\nUnique Requirements\...
# 3  Roles & Responsibilities\nWork for a Fortune 5...
# 4  Roles & Responsibilities\nJob Summary\nAn exci...
#
#                                         requirements
# 0  Requirements\n**Apply here**\nhttps://www.blue...
# 1  Requirements\nMinimum qualifications:\n- BA/BS...
# 2  Requirements\nDegree in Information Systems, B...
# 3  Requirements\nThe successful candidate will be...
# 4  Requirements\nMandatory Skill-set\nDegree in C...

# %%
df= dff[["title","location","employment_type","level","category","description","requirements"]]

# %%
def text_preprocessing(x):
    words = re.sub('[^a-zA-Z]', ' ', x).lower().split()
    lemma = nltk.wordnet.WordNetLemmatizer()
    words = [lemma.lemmatize(word) for word in words]
    words = ' '.join(words)
    return words

# %%
df = df.applymap(text_preprocessing)

# %%
# Remove sub-titles in job description and requirements.
df['description'] = df['description'].str.replace('role responsibility', ' ')
df['requirements'] = df['requirements'].str.replace('requirement', ' ')
df.head()
# Out:
#                                                title    location  \
# 0  credit risk analyst leading renewable energy t...     central
# 1  financial analyst google customer solution sin...       south
# 2                            senior business analyst     central
# 3            senior financial analyst pharmaceutical  islandwide
# 4                             system analyst java jd        east
#
#       employment_type                       level  \
# 0           full time                professional
# 1           full time                   executive
# 2           permanent                professional
# 3           permanent            senior executive
# 4  contract full time  executive senior executive
#
#                               category  \
# 0  risk management banking and finance
# 1                  banking and finance
# 2               information technology
# 3         accounting auditing taxation
# 4                        entertainment
#
#                                          description  \
# 0    year of relevant experience renewable energy...
# 1    company overview google is not a conventiona...
# 2    unique requirement strong understanding of p...
# 3    work for a fortune u mnc financial planning ...
# 4    job summary an exciting opportunity for java...
#
#                                         requirements
# 0    apply here http www bluechipcareers asia com...
# 1    minimum qualification ba b degree or equival...
# 2    degree in information system business admini...
# 3    the successful candidate will be professiona...
# 4    mandatory skill set degree in computer scien...

# %%
vectorizer= TfidfVectorizer(ngram_range=(1,3))

# %%
tfidf= vectorizer.fit_transform(df["requirements"])

# %%
def job_rec(skills):
    
    skills=text_preprocessing(skills)
    
    query_vec= vectorizer.transform([skills])
    
    similarity= cosine_similarity(query_vec, tfidf).flatten()
    
    indice= np.argpartition(similarity, -5)[-5:]    #Recuperation des 5 qqQQQQQQQindices les plus similaires
    
    
    result= dff.iloc[indice][::-1] # recommandation des job les plus similaires aux compétences entrées
    
    return result

# %%
job_rec("python java")
# Out:
#                                          title        location  \
# 131                               Data Analyst         Central
# 509                             System Analyst      Islandwide
# 550                Technology Analyst - Python         Central
# 1003  Lead Systems Analyst, Mobile Application            West
# 1133                        ANALYST PROGRAMMER  South, Central
#
#            employment_type                            level  \
# 131   Permanent, Full Time  Fresh/entry level, Professional
# 509              Full Time                 Senior Executive
# 550              Full Time                 Senior Executive
# 1003             Full Time      Executive, Senior Executive
# 1133   Contract, Full Time                        Executive
#
#                                                category salary_min salary_max  \
# 131                 Engineering, Information Technology     $4,000   to$5,200
# 509                              Information Technology     $5,600   to$7,000
# 550                              Information Technology        NaN        NaN
# 1003  Information Technology, Others, Telecommunicat...     $3,500   to$7,000
# 1133                             Information Technology     $4,700   to$7,000
#
#      salary_type                                        description  \
# 131      Monthly  Roles & Responsibilities\nPropertyGuru Group i...
# 509      Monthly  Roles & Responsibilities\nDevelopment of Web-b...
# 550          NaN  Roles & Responsibilities\nDesign, develop, tes...
# 1003     Monthly  Roles & Responsibilities\nLead the mobile appl...
# 1133     Monthly  Roles & Responsibilities\nSystem Development, ...
#
#                                            requirements
# 131   Requirements\nBachelor’s degree in IT or relev...
# 509   Requirements\nAt Least 3 Years web-based enter...
# 550   Requirements\nStrong in Python or any classic ...
# 1003  Requirements\nDegree in in Computer Science wi...
# 1133  Requirements\nStrong technical skills in JAVA ...

# %%
# Création d'une interface
import ipywidgets as widgets
from IPython.display import display



job_input= widgets.Text(
value= "Entrez vos compétences",
description="Job Recom",
disable= False
)


job_list= widgets.Output()

def on_type(data):
    with job_list:
        job_list.clear_output()
        skills=data["new"]
        if len(skills)>5:
            display(job_rec(skills))
        
job_input.observe(on_type, names="value")
display(job_input, job_list)
# Out:
# Text(value='Entrez vos compétences', description='Job Recom')
# Output()
